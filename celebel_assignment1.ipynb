# %%
#1.Load a CSV dataset into a Pandas DataFrame
import pandas as pd
df1=pd.read_csv("Combined_dataset.csv")

# %%
#2.Explore data (head/tail, shape, columns, data types).
df1.head(2)
# Out:
#    product_id           title                product_description  rating  \
# 0     8376765     Lino Perros     Women Navy Blue Solid Backpack     3.8
# 1     9136281  Tommy Hilfiger  Unisex Navy Blue Striped Backpack     4.5
#
#    ratings_count  initial_price  discount  final_price currency  \
# 0             15           3995      58.0  "₹3,995.00"      INR
# 1             67           2899      35.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
#
#   seller_name                 sizes                 videos seller_information  \
# ...

# %%
df1.tail(10)
# Out:
#      product_id              title  \
# 990     9053317          TIMESMITH
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 993    19322504                V2A
# 994     8481603  French Connection
# 995    13698258              KREDO
# 996    16896006              GUESS
# 997     1708108           GIORDANO
# 998    19280114           Fastrack
# 999    18601682            BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 990                   Men Black Analogue Watch TSC-008     3.7            304
# 991               Women Brown Analogue Watch DK11467-6     4.4            940
# 992  Youth Digital Women Red Digital Watch I117 DW-...     4.6             29
# 993  Girls Blue Printed Dial & Pink Straps Digital ...     4.0              6
# 994         Women Silver-Toned Analogue Watch FCN0001B     4.5            149
# 995  Men FORTE Silver Automatic Skeleton Analogue W...     3.5             11
# ...

# %%
df1.shape
# Out:
# (1000, 24)

# %%
df1.shape[0]
# Out:
# 1000

# %%
df1.shape[1]
# Out:
# 24

# %%
df1.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df1.columns[2]
# Out:
# 'product_description'

# %%
df1.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df1["rating"].dtypes
# Out:
# dtype('float64')

# %%
#3.Handle missing values (identify, fill/drop).

df1.isnull().head(10)
# Out:
#    product_id  title  product_description  Quantity  rating  ratings_count  \
# 0       False  False                False     False   False          False
# 1       False  False                False     False   False          False
# 2       False  False                False     False   False          False
# 3       False  False                False     False   False          False
# 4       False  False                False     False   False          False
# 5       False  False                False     False   False          False
# 6       False  False                False     False   False          False
# 7       False  False                False     False   False          False
# 8       False  False                False     False   False          False
# 9       False  False                False     False   False          False
#
#    initial_price  discount  final_price  currency  ...  what_customers_said  \
# ...

# %%
df1.dropna()
# Out:
#      product_id            title  \
# 418    18689340   Flying Machine
# 752    18241626         Roadster
# 753    18241400         Roadster
# 754    18241644         Roadster
# 755    18240570    all about you
# 756    18240582    all about you
# 757    18337610         Roadster
# 760    18241294         Roadster
# 762    18241298         Roadster
# 904    18937522  her by invictus
#
#                                    product_description  rating  ratings_count  \
# 418  Women Black Wide Leg High-Rise Light Fade Crop...     4.3             36
# 752  The  Lifestyle Co. Women Maroon & Black Ribbed...     4.5             25
# 753     Women Black & White Geometric Pullover Sweater     3.8             57
# 754     The  Lifestyle Co. Women Pink Acrylic Pullover     4.3             55
# 755             Women Navy Blue & Red Checked Pullover     4.3             53
# 756                   Women Maroon Cable Knit Pullover     4.4             39
# ...

# %%
df1.dropna(axis=1).head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 4         2     4.7             12           2899      17.0       2899.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
df1.fillna("celebal").head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 4         2     4.7             12           2899      17.0       2899.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
df1.ffill(inplace=True)

# %%
df1.bfill(inplace=True)

# %%
#4.Perform basic operations (filter rows, select columns).
df1["product_description"]
# Out:
# 0                         Women Navy Blue Solid Backpack
# 1                      Unisex Navy Blue Striped Backpack
# 2                         Aries Women Pink Mini Backpack
# 3             Unisex Navy & Grey Printed Burner Backpack
# 4                               Men Blue Solid Bath Robe
#                              ...
# 995    Men FORTE Silver Automatic Skeleton Analogue W...
# 996    Women White Patterned Dial & White Straps Anal...
# 997    Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    Men Black Brass Dial & Black Stainless Steel S...
# 999                             Purple Textured Yoga Mat
# Name: product_description, Length: 1000, dtype: object

# %%
df1[["product_id","title","rating"]].head()
# Out:
#    product_id           title  rating
# 0     8376765     Lino Perros     3.8
# 1     9136281  Tommy Hilfiger     4.5
# 2    17633752           Lavie     4.4
# 3     1376949          F Gear     4.4
# 4    13939916       MYTRIDENT     4.7

# %%
df1[df1["rating"]>=4].head()
# Out:
#    product_id           title                         product_description  \
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
# 5    17198778             H&M  Beige & Tan Solid Stoneware Soap Dispenser
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
# 5     4.5             42           1399      17.0  "₹1,399.00"      INR
#
#                                               images  ...  \
# ...

# %%
df1[df1["initial_price"]<=500].head()
# Out:
#     product_id                    title  \
# 25    22063882  GROVERSONS Paris Beauty
# 31    18223842                      max
# 32    18656766                    VStar
# 33    18656764                    VStar
# 41    18532334               Pepe Jeans
#
#                                  product_description  rating  ratings_count  \
# 25  Non Padded Cotton Seamless Non-Wired T-shirt Bra     4.0             25
# 31                          Plus Size Non Padded Bra     4.1             37
# 32                           Beige Solid T-Shirt Bra     4.6              5
# 33                            Grey Solid T-Shirt Bra     4.3              6
# 41             Men Green Printed Cotton Basic Briefs     0.0              0
#
#     initial_price  discount final_price currency  \
# 25            399      25.0   "₹299.00"      INR
# 31            449      20.0   "₹449.00"      INR
# 32            345      20.0   "₹345.00"      INR
# 33            345      20.0   "₹345.00"      INR
# ...

# %%
df1[(df1["initial_price"] > 100) & (df1["discount"] > 20)].head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 6    19851824      AVI Living   Grey Solid 500 GSM Pure Cotton Bath Towel
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 6         2     4.0              5           1399      65.0       1399.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
df1.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
print(df1.duplicated().sum())
# Out:
# 0

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.drop_duplicates(subset=["product_id"], inplace=True)

# %%
df1.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 4         2     4.7             12           2899      17.0       2899.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
df1.insert(3,"Quantity",2)

# %%
df1.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 4         2     4.7             12           2899      17.0       2899.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
#6.Create a derived column (total_amount = price * quantity).
df1["final_price"] = df1["final_price"].replace('[₹,"]', '', regex=True)
df1["final_price"] = df1["final_price"].astype(float)
print(df1["final_price"].dtype)
# Out:
# float64

# %%
df1["total_amount"]=df1["Quantity"]*df1["final_price"]

# %%
df1.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    Quantity  rating  ratings_count  initial_price  discount  final_price  \
# 0         2     3.8             15           3995      58.0       3995.0
# 1         2     4.5             67           2899      35.0       2899.0
# 2         2     4.4            226           2999      65.0       2999.0
# 3         2     4.4           1052           1675      52.0       1675.0
# 4         2     4.7             12           2899      17.0       2899.0
#
#   currency  ...                                what_customers_said  \
# ...

# %%
df1.to_csv("cleaned_dataset.csv", index=False)
